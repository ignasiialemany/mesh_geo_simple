# %%
import sympy as sp
import numpy as np

CV = 0.25
l_x = 8
l_y = 16
l_z = 110
delta_block = 1

dx = sp.symbols('dx')

Xblock = 2*delta_block + l_x*3 + 2*dx
Yblock = 2*delta_block + l_y*3 + 2*dx
Zblock = 2*delta_block + l_z 
rho_ecv = 1 - (9*l_x*l_y*l_z)/(Xblock*Yblock*Zblock)

# Print the expanded equation
equation = rho_ecv - CV
print("Expanded equation:")
print(equation, "= 0")

# Find real solutions only
real_solutions = sp.solve(equation, dx, domain='RR')

print("\nReal solutions:")
print(real_solutions)

# If solutions exist, validate them
if real_solutions:
    for sol in real_solutions:
        # Use N() for numerical evaluation instead of float conversion
        sol_num = np.complex128(sol)
        sol_num = sol_num.real
        sol_num = float(sol_num)
        print(type(sol_num))
        print(f"\nValidation for dx = {sol_num}:")
        # Check if this solution gives the desired CV
        result = 1 - (9*l_x*l_y*l_z)/((2*delta_block + l_x*3 + 2*sol_num)*(2*delta_block + l_y*3 + 2*sol_num)*(2*delta_block + l_z))
        print(f"Resulting CV = {sp.N(result):.6f}")
# Out:
# Expanded equation:
# 0.75 - 7920/(7*(2*dx + 26)*(2*dx + 50)) = 0
#
# Real solutions:
# [-39.3259158992370, 1.32591589923704]
# <class 'float'>
#
# Validation for dx = -39.32591589923704:
# Resulting CV = 0.250000
# <class 'float'>
#
# Validation for dx = 1.3259158992370415:
# Resulting CV = 0.250000

# %%
dx = 1.33
rho_ecv = 1-(9*l_x*l_y*l_z)/((2*delta_block + l_x*3 + 2*dx)*(2*delta_block + l_y*3 + 2*dx)*(2*delta_block + l_z))
print(f"ECV = {rho_ecv*100:.2f}%")
print("X block = ", 2*delta_block + l_x*3 + 2*dx)
print("Y block = ", 2*delta_block + l_y*3 + 2*dx)
print("Z block = ", 2*delta_block + l_z)
# Out:
# ECV = 25.03%
# X block =  28.66
# Y block =  52.66
# Z block =  112

# %% [markdown]
# Function to add 3D rectangular prism given the sides lx,ly,lz and center (on low=z) through gmsh py

# %%
import gmsh

def add_cuboid(center, lx, ly, lz, lc=10.):
    cx, cy, cz = center
    hx, hy = lx / 2, ly / 2
    
    # Define the points of the cuboid:
    p1 = gmsh.model.geo.add_point(cx - hx, cy - hy, cz, lc)
    p2 = gmsh.model.geo.add_point(cx + hx, cy - hy, cz, lc)
    p3 = gmsh.model.geo.add_point(cx + hx, cy + hy, cz, lc)
    p4 = gmsh.model.geo.add_point(cx - hx, cy + hy, cz, lc)
    
    p5 = gmsh.model.geo.add_point(cx - hx, cy + hy, cz + lz, lc)
    p6 = gmsh.model.geo.add_point(cx - hx, cy - hy, cz + lz, lc)
    p7 = gmsh.model.geo.add_point(cx + hx, cy - hy, cz + lz, lc)
    p8 = gmsh.model.geo.add_point(cx + hx, cy + hy, cz + lz, lc)

    # Define the edges of the cuboid:
    l1 = gmsh.model.geo.add_line(p1, p2)
    l2 = gmsh.model.geo.add_line(p2, p3)
    l3 = gmsh.model.geo.add_line(p3, p4)
    l4 = gmsh.model.geo.add_line(p4, p1)
    l5 = gmsh.model.geo.add_line(p5, p6)
    l6 = gmsh.model.geo.add_line(p6, p7)
    l7 = gmsh.model.geo.add_line(p7, p8)
    l8 = gmsh.model.geo.add_line(p8, p5)
    
    l9 = gmsh.model.geo.add_line(p4, p5)
    l10 = gmsh.model.geo.add_line(p6, p1)
    l11 = gmsh.model.geo.add_line(p7, p2)
    l12 = gmsh.model.geo.add_line(p3, p8)

    # Define the faces of the cuboid:
    cl1 = gmsh.model.geo.add_curve_loop([-l1, -l2, -l3, -l4])
    cl2 = gmsh.model.geo.add_curve_loop([l5, l6, l7, l8])
    cl3 = gmsh.model.geo.add_curve_loop([-l9, -l5, -l10, +l4])
    cl4 = gmsh.model.geo.add_curve_loop([l9, -l8, -l12, l3])
    cl5 = gmsh.model.geo.add_curve_loop([-l6, -l11, +l1, +l10])
    cl6 = gmsh.model.geo.add_curve_loop([l11, l2, l12, -l7])

    # Create the surfaces of the cuboid:
    s1 = gmsh.model.geo.add_plane_surface([cl1])
    s2 = gmsh.model.geo.add_plane_surface([cl2])
    s3 = gmsh.model.geo.add_plane_surface([cl3])
    s4 = gmsh.model.geo.add_plane_surface([cl4])
    s5 = gmsh.model.geo.add_plane_surface([cl5])
    s6 = gmsh.model.geo.add_plane_surface([cl6])

    # Synchronize to create the volume:
    gmsh.model.geo.synchronize()

    # Create a surface loop and volume:
    sl = gmsh.model.geo.add_surface_loop([s1, s2, s3, s4, s5, s6])

# %%
import trimesh

def create_mesh(l_x, l_y, l_z,folder):

    #hardcoded values for center and dx, delta_block
    delta_block = 1
    dx = 1.33
    dy = 1.33
    center_x = delta_block + 8/2
    center_y = delta_block + 16/2
    center_z = delta_block
    counter = 0

    for i in range (0,3):
        for j in range (0,3):
            center = [center_x, center_y]
            center[0] += (8+dx)*i
            center[1] += (16+dy)*j
            gmsh.initialize()
            
            add_cuboid((center[0], center[1], center_z), l_x, l_y, l_z)

            gmsh.model.mesh.generate(2)

            # Write mesh data to file:
            gmsh.write(f"{folder}/cuboid_{counter}.msh")

            gmsh.finalize()

            import meshio

            mesh = meshio.read(f"{folder}/cuboid_{counter}.msh")

            triangle_cells = [cell for cell in mesh.cells if cell.type == "triangle"]

            triangle_mesh = meshio.Mesh(points=mesh.points, cells=triangle_cells)

            triangle_mesh.write(
                f"{folder}/cuboid_{counter}.ply",  # str, os.PathLike, or buffer/open file
                file_format="ply"
            )
            
            mesh_check = trimesh.load(f"{folder}/cuboid_{counter}.ply")
            
            if not mesh_check.is_watertight:
                print("Mesh is not watertight.")
                #raise RuntimeError("Mesh is not watertight.")
            
            # Ensure normals are consistent and pointing outward
            if not mesh_check.is_winding_consistent:
                mesh_check.fix_normals()
                    
            # Make sure volume is positive
            if mesh_check.volume < 0:
                mesh_check.invert()
                    
            mesh_check.remove_degenerate_faces()
            mesh_check.remove_duplicate_faces()
            
            if not mesh_check.is_watertight:
                print("Mesh is not watertight after fixing.")
                raise RuntimeError("Mesh is not watertight after fixing.")
            
            if not mesh_check.is_winding_consistent:
                print("Mesh winding is not consistent after fixing.")
                raise RuntimeError("Mesh winding is not consistent after fixing.")

            mesh_check.export(f"{folder}/cuboid_{counter}.off")
            print(f"Mesh successfully exported to simple_domain/cuboid_{0}.off")
            counter += 1

# %%
import os
dx = 1.33
l_x = 8
l_y = 16
l_z = 110
delta_block = 1
block_x_original = 2*delta_block + l_x*3 + 2*dx
block_y_original= 2*delta_block + l_y*3 + 2*dx
block_z_original = 2*delta_block + l_z

l_x_updated = l_x*1.045
l_y_updated = l_y*1.045
l_z_updated = l_z
 
print(l_x_updated, l_y_updated, l_z_updated)

rho_ecv = 1 - (9*l_x_updated*l_y_updated*l_z_updated)/(block_x_original*block_y_original*block_z_original)
print(f"ECV = {rho_ecv*100:.2f}%")
#rho_ecv = np.round(rho_ecv,2)
#create folder with name simple_domain_ECV_rho_ecv
#os.makedirs(f"simple_domain_ECV_{rho_ecv}", exist_ok=True)
#create_mesh(l_x, l_y, l_z, delta_block, dx, f"simple_domain_ECV_{rho_ecv}")
# Out:
# 8.36 16.72 110
# ECV = 18.13%

# %%
#We are doing now geometry starting at relaxed state
ratios_ECV = [0.86,1, 1.045]
lx = 8
ly = 16
lz = 110

for ratio in ratios_ECV:
    lx_ratio = ratio*lx
    ly_ratio = ratio*ly
    lz_ratio = lz
    rho_ecv = 1 - (9*lx_ratio*ly_ratio*lz_ratio)/(block_x_original*block_y_original*block_z_original)
    print(f"ECV = {rho_ecv*100:.2f}%")
    rho_ecv = np.round(rho_ecv,2)
    #create folder with name simple_domain_ECV_rho_ecv
    os.makedirs(f"relaxed_state/simple_domain_ECV_{rho_ecv}", exist_ok=True)
    create_mesh(lx_ratio, ly_ratio, lz, f"relaxed_state/simple_domain_ECV_{rho_ecv}")
# Out:
# ECV = 44.55%
# Info    : Increasing process stack size (8176 kB < 16 MB)
# Info    : Meshing 1D...
# Info    : [  0%] Meshing curve 1 (Line)
# Info    : [ 10%] Meshing curve 2 (Line)
# Info    : [ 20%] Meshing curve 3 (Line)
# Info    : [ 30%] Meshing curve 4 (Line)
# Info    : [ 40%] Meshing curve 5 (Line)
# Info    : [ 50%] Meshing curve 6 (Line)
# Info    : [ 60%] Meshing curve 7 (Line)
# Info    : [ 60%] Meshing curve 8 (Line)
# Info    : [ 70%] Meshing curve 9 (Line)
# Info    : [ 80%] Meshing curve 10 (Line)
# Info    : [ 90%] Meshing curve 11 (Line)
# Info    : [100%] Meshing curve 12 (Line)
# Info    : Done meshing 1D (Wall 0.000415209s, CPU 0.000521s)
# Info    : Meshing 2D...
# Info    : [  0%] Meshing surface 1 (Plane, Frontal-Delaunay)
# Info    : [ 20%] Meshing surface 2 (Plane, Frontal-Delaunay)
# Info    : [ 40%] Meshing surface 3 (Plane, Frontal-Delaunay)
# Info    : [ 60%] Meshing surface 4 (Plane, Frontal-Delaunay)
# Info    : [ 70%] Meshing surface 5 (Plane, Frontal-Delaunay)
# Info    : [ 90%] Meshing surface 6 (Plane, Frontal-Delaunay)
# Info    : Done meshing 2D (Wall 0.00205142s, CPU 0.00195s)
# Info    : 104 nodes 268 elements
# Info    : Writing 'relaxed_state/simple_domain_ECV_0.45/cuboid_0.msh'...
# Info    : Done writing 'relaxed_state/simple_domain_ECV_0.45/cuboid_0.msh'
#
# Mesh successfully exported to simple_domain/cuboid_0.off
# Info    : Increasing process stack size (8176 kB < 16 MB)
# Info    : Meshing 1D...
# Info    : [  0%] Meshing curve 1 (Line)
# Info    : [ 10%] Meshing curve 2 (Line)
# Info    : [ 20%] Meshing curve 3 (Line)
# Info    : [ 30%] Meshing curve 4 (Line)
# Info    : [ 40%] Meshing curve 5 (Line)
# Info    : [ 50%] Meshing curve 6 (Line)
# Info    : [ 60%] Meshing curve 7 (Line)
# Info    : [ 60%] Meshing curve 8 (Line)
# Info    : [ 70%] Meshing curve 9 (Line)
# Info    : [ 80%] Meshing curve 10 (Line)
# Info    : [ 90%] Meshing curve 11 (Line)
# Info    : [100%] Meshing curve 12 (Line)
# Info    : Done meshing 1D (Wall 0.00044825s, CPU 0.000508s)
# Info    : Meshing 2D...
# Info    : [  0%] Meshing surface 1 (Plane, Frontal-Delaunay)
# Info    : [ 20%] Meshing surface 2 (Plane, Frontal-Delaunay)
# Info    : [ 40%] Meshing surface 3 (Plane, Frontal-Delaunay)
# Info    : [ 60%] Meshing surface 4 (Plane, Frontal-Delaunay)
# Info    : [ 70%] Meshing surface 5 (Plane, Frontal-Delaunay)
# Info    : [ 90%] Meshing surface 6 (Plane, Frontal-Delaunay)
# Info    : Done meshing 2D (Wall 0.00200008s, CPU 0.002035s)
# Info    : 104 nodes 268 elements
# Info    : Writing 'relaxed_state/simple_domain_ECV_0.45/cuboid_1.msh'...
# Info    : Done writing 'relaxed_state/simple_domain_ECV_0.45/cuboid_1.msh'
#
# Mesh successfully exported to simple_domain/cuboid_0.off
# Info    : Increasing process stack size (8176 kB < 16 MB)
# Info    : Meshing 1D...
# Info    : [  0%] Meshing curve 1 (Line)
# Info    : [ 10%] Meshing curve 2 (Line)
# Info    : [ 20%] Meshing curve 3 (Line)
# Info    : [ 30%] Meshing curve 4 (Line)
# Info    : [ 40%] Meshing curve 5 (Line)
# Info    : [ 50%] Meshing curve 6 (Line)
# Info    : [ 60%] Meshing curve 7 (Line)
# Info    : [ 60%] Meshing curve 8 (Line)
# Info    : [ 70%] Meshing curve 9 (Line)
# Info    : [ 80%] Meshing curve 10 (Line)
# Info    : [ 90%] Meshing curve 11 (Line)
# Info    : [100%] Meshing curve 12 (Line)
# Info    : Done meshing 1D (Wall 0.000419459s, CPU 0.000527s)
# Info    : Meshing 2D...
# Info    : [  0%] Meshing surface 1 (Plane, Frontal-Delaunay)
# Info    : [ 20%] Meshing surface 2 (Plane, Frontal-Delaunay)
# Info    : [ 40%] Meshing surface 3 (Plane, Frontal-Delaunay)
# Info    : [ 60%] Meshing surface 4 (Plane, Frontal-Delaunay)
# Info    : [ 70%] Meshing surface 5 (Plane, Frontal-Delaunay)
# Info    : [ 90%] Meshing surface 6 (Plane, Frontal-Delaunay)
# Info    : Done meshing 2D (Wall 0.00201871s, CPU 0.002041s)
# Info    : 104 nodes 268 elements
# Info    : Writing 'relaxed_state/simple_domain_ECV_0.45/cuboid_2.msh'...
# Info    : Done writing 'relaxed_state/simple_domain_ECV_0.45/cuboid_2.msh'
#
# Mesh successfully exported to simple_domain/cuboid_0.off
# Info    : Increasing process stack size (8176 kB < 16 MB)
# Info    : Meshing 1D...
# Info    : [  0%] Meshing curve 1 (Line)
# Info    : [ 10%] Meshing curve 2 (Line)
# Info    : [ 20%] Meshing curve 3 (Line)
# Info    : [ 30%] Meshing curve 4 (Line)
# Info    : [ 40%] Meshing curve 5 (Line)
# Info    : [ 50%] Meshing curve 6 (Line)
# Info    : [ 60%] Meshing curve 7 (Line)
# Info    : [ 60%] Meshing curve 8 (Line)
# Info    : [ 70%] Meshing curve 9 (Line)
# Info    : [ 80%] Meshing curve 10 (Line)
# Info    : [ 90%] Meshing curve 11 (Line)
# Info    : [100%] Meshing curve 12 (Line)
# Info    : Done meshing 1D (Wall 0.000456125s, CPU 0.00051s)
# Info    : Meshing 2D...
# Info    : [  0%] Meshing surface 1 (Plane, Frontal-Delaunay)
# Info    : [ 20%] Meshing surface 2 (Plane, Frontal-Delaunay)
# Info    : [ 40%] Meshing surface 3 (Plane, Frontal-Delaunay)
# Info    : [ 60%] Meshing surface 4 (Plane, Frontal-Delaunay)
# Info    : [ 70%] Meshing surface 5 (Plane, Frontal-Delaunay)
# Info    : [ 90%] Meshing surface 6 (Plane, Frontal-Delaunay)
# Info    : Done meshing 2D (Wall 0.0017925s, CPU 0.00181s)
# Info    : 104 nodes 268 elements
# Info    : Writing 'relaxed_state/simple_domain_ECV_0.45/cuboid_3.msh'...
# Info    : Done writing 'relaxed_state/simple_domain_ECV_0.45/cuboid_3.msh'
#
# Mesh successfully exported to simple_domain/cuboid_0.off
# Info    : Increasing process stack size (8176 kB < 16 MB)
# Info    : Meshing 1D...
# Info    : [  0%] Meshing curve 1 (Line)
# Info    : [ 10%] Meshing curve 2 (Line)
# Info    : [ 20%] Meshing curve 3 (Line)
# Info    : [ 30%] Meshing curve 4 (Line)
# Info    : [ 40%] Meshing curve 5 (Line)
# Info    : [ 50%] Meshing curve 6 (Line)
# Info    : [ 60%] Meshing curve 7 (Line)
# Info    : [ 60%] Meshing curve 8 (Line)
# Info    : [ 70%] Meshing curve 9 (Line)
# Info    : [ 80%] Meshing curve 10 (Line)
# Info    : [ 90%] Meshing curve 11 (Line)
# Info    : [100%] Meshing curve 12 (Line)
# Info    : Done meshing 1D (Wall 0.000414459s, CPU 0.000452s)
# Info    : Meshing 2D...
# Info    : [  0%] Meshing surface 1 (Plane, Frontal-Delaunay)
# Info    : [ 20%] Meshing surface 2 (Plane, Frontal-Delaunay)
# Info    : [ 40%] Meshing surface 3 (Plane, Frontal-Delaunay)
# Info    : [ 60%] Meshing surface 4 (Plane, Frontal-Delaunay)
# Info    : [ 70%] Meshing surface 5 (Plane, Frontal-Delaunay)
# Info    : [ 90%] Meshing surface 6 (Plane, Frontal-Delaunay)
# Info    : Done meshing 2D (Wall 0.00275292s, CPU 0.002066s)
# Info    : 104 nodes 268 elements
# Info    : Writing 'relaxed_state/simple_domain_ECV_0.45/cuboid_4.msh'...
# Info    : Done writing 'relaxed_state/simple_domain_ECV_0.45/cuboid_4.msh'
#
# Mesh successfully exported to simple_domain/cuboid_0.off
# Info    : Increasing process stack size (8176 kB < 16 MB)
# Info    : Meshing 1D...
# Info    : [  0%] Meshing curve 1 (Line)
# Info    : [ 10%] Meshing curve 2 (Line)
# Info    : [ 20%] Meshing curve 3 (Line)
# Info    : [ 30%] Meshing curve 4 (Line)
# Info    : [ 40%] Meshing curve 5 (Line)
# Info    : [ 50%] Meshing curve 6 (Line)
# Info    : [ 60%] Meshing curve 7 (Line)
# Info    : [ 60%] Meshing curve 8 (Line)
# Info    : [ 70%] Meshing curve 9 (Line)
# Info    : [ 80%] Meshing curve 10 (Line)
# Info    : [ 90%] Meshing curve 11 (Line)
# Info    : [100%] Meshing curve 12 (Line)
# Info    : Done meshing 1D (Wall 0.0004235s, CPU 0.000466s)
# Info    : Meshing 2D...
# Info    : [  0%] Meshing surface 1 (Plane, Frontal-Delaunay)
# Info    : [ 20%] Meshing surface 2 (Plane, Frontal-Delaunay)
# Info    : [ 40%] Meshing surface 3 (Plane, Frontal-Delaunay)
# Info    : [ 60%] Meshing surface 4 (Plane, Frontal-Delaunay)
# Info    : [ 70%] Meshing surface 5 (Plane, Frontal-Delaunay)
# Info    : [ 90%] Meshing surface 6 (Plane, Frontal-Delaunay)
# Info    : Done meshing 2D (Wall 0.00185571s, CPU 0.001862s)
# Info    : 104 nodes 268 elements
# Info    : Writing 'relaxed_state/simple_domain_ECV_0.45/cuboid_5.msh'...
# Info    : Done writing 'relaxed_state/simple_domain_ECV_0.45/cuboid_5.msh'
#
# Mesh successfully exported to simple_domain/cuboid_0.off
# Info    : Increasing process stack size (8176 kB < 16 MB)
# Info    : Meshing 1D...
# Info    : [  0%] Meshing curve 1 (Line)
# Info    : [ 10%] Meshing curve 2 (Line)
# Info    : [ 20%] Meshing curve 3 (Line)
# Info    : [ 30%] Meshing curve 4 (Line)
# Info    : [ 40%] Meshing curve 5 (Line)
# Info    : [ 50%] Meshing curve 6 (Line)
# Info    : [ 60%] Meshing curve 7 (Line)
# Info    : [ 60%] Meshing curve 8 (Line)
# Info    : [ 70%] Meshing curve 9 (Line)
# Info    : [ 80%] Meshing curve 10 (Line)
# Info    : [ 90%] Meshing curve 11 (Line)
# Info    : [100%] Meshing curve 12 (Line)
# Info    : Done meshing 1D (Wall 0.000452292s, CPU 0.000481s)
# Info    : Meshing 2D...
# Info    : [  0%] Meshing surface 1 (Plane, Frontal-Delaunay)
# Info    : [ 20%] Meshing surface 2 (Plane, Frontal-Delaunay)
# Info    : [ 40%] Meshing surface 3 (Plane, Frontal-Delaunay)
# Info    : [ 60%] Meshing surface 4 (Plane, Frontal-Delaunay)
# Info    : [ 70%] Meshing surface 5 (Plane, Frontal-Delaunay)
# Info    : [ 90%] Meshing surface 6 (Plane, Frontal-Delaunay)
# Info    : Done meshing 2D (Wall 0.00182804s, CPU 0.001842s)
# Info    : 104 nodes 268 elements
# Info    : Writing 'relaxed_state/simple_domain_ECV_0.45/cuboid_6.msh'...
# Info    : Done writing 'relaxed_state/simple_domain_ECV_0.45/cuboid_6.msh'
#
# Mesh successfully exported to simple_domain/cuboid_0.off
# Info    : Increasing process stack size (8176 kB < 16 MB)
# Info    : Meshing 1D...
# Info    : [  0%] Meshing curve 1 (Line)
# Info    : [ 10%] Meshing curve 2 (Line)
# Info    : [ 20%] Meshing curve 3 (Line)
# Info    : [ 30%] Meshing curve 4 (Line)
# Info    : [ 40%] Meshing curve 5 (Line)
# Info    : [ 50%] Meshing curve 6 (Line)
# Info    : [ 60%] Meshing curve 7 (Line)
# Info    : [ 60%] Meshing curve 8 (Line)
# Info    : [ 70%] Meshing curve 9 (Line)
# Info    : [ 80%] Meshing curve 10 (Line)
# Info    : [ 90%] Meshing curve 11 (Line)
# Info    : [100%] Meshing curve 12 (Line)
# Info    : Done meshing 1D (Wall 0.00045s, CPU 0.000502s)
# Info    : Meshing 2D...
# Info    : [  0%] Meshing surface 1 (Plane, Frontal-Delaunay)
# Info    : [ 20%] Meshing surface 2 (Plane, Frontal-Delaunay)
# Info    : [ 40%] Meshing surface 3 (Plane, Frontal-Delaunay)
# Info    : [ 60%] Meshing surface 4 (Plane, Frontal-Delaunay)
# Info    : [ 70%] Meshing surface 5 (Plane, Frontal-Delaunay)
# Info    : [ 90%] Meshing surface 6 (Plane, Frontal-Delaunay)
# Info    : Done meshing 2D (Wall 0.00184213s, CPU 0.002225s)
# Info    : 104 nodes 268 elements
# Info    : Writing 'relaxed_state/simple_domain_ECV_0.45/cuboid_7.msh'...
# Info    : Done writing 'relaxed_state/simple_domain_ECV_0.45/cuboid_7.msh'
#
# Mesh successfully exported to simple_domain/cuboid_0.off
# Info    : Increasing process stack size (8176 kB < 16 MB)
# Info    : Meshing 1D...
# Info    : [  0%] Meshing curve 1 (Line)
# Info    : [ 10%] Meshing curve 2 (Line)
# Info    : [ 20%] Meshing curve 3 (Line)
# Info    : [ 30%] Meshing curve 4 (Line)
# Info    : [ 40%] Meshing curve 5 (Line)
# Info    : [ 50%] Meshing curve 6 (Line)
# Info    : [ 60%] Meshing curve 7 (Line)
# Info    : [ 60%] Meshing curve 8 (Line)
# Info    : [ 70%] Meshing curve 9 (Line)
# Info    : [ 80%] Meshing curve 10 (Line)
# Info    : [ 90%] Meshing curve 11 (Line)
# Info    : [100%] Meshing curve 12 (Line)
# Info    : Done meshing 1D (Wall 0.000437792s, CPU 0.000535s)
# Info    : Meshing 2D...
# Info    : [  0%] Meshing surface 1 (Plane, Frontal-Delaunay)
# Info    : [ 20%] Meshing surface 2 (Plane, Frontal-Delaunay)
# Info    : [ 40%] Meshing surface 3 (Plane, Frontal-Delaunay)
# Info    : [ 60%] Meshing surface 4 (Plane, Frontal-Delaunay)
# Info    : [ 70%] Meshing surface 5 (Plane, Frontal-Delaunay)
# Info    : [ 90%] Meshing surface 6 (Plane, Frontal-Delaunay)
# Info    : Done meshing 2D (Wall 0.00199183s, CPU 0.00199s)
# Info    : 104 nodes 268 elements
# Info    : Writing 'relaxed_state/simple_domain_ECV_0.45/cuboid_8.msh'...
# Info    : Done writing 'relaxed_state/simple_domain_ECV_0.45/cuboid_8.msh'
#
# Mesh successfully exported to simple_domain/cuboid_0.off
# ECV = 25.03%
# Info    : Increasing process stack size (8176 kB < 16 MB)
# Info    : Meshing 1D...
# Info    : [  0%] Meshing curve 1 (Line)
# Info    : [ 10%] Meshing curve 2 (Line)
# Info    : [ 20%] Meshing curve 3 (Line)
# Info    : [ 30%] Meshing curve 4 (Line)
# Info    : [ 40%] Meshing curve 5 (Line)
# Info    : [ 50%] Meshing curve 6 (Line)
# Info    : [ 60%] Meshing curve 7 (Line)
# Info    : [ 60%] Meshing curve 8 (Line)
# Info    : [ 70%] Meshing curve 9 (Line)
# Info    : [ 80%] Meshing curve 10 (Line)
# Info    : [ 90%] Meshing curve 11 (Line)
# Info    : [100%] Meshing curve 12 (Line)
# Info    : Done meshing 1D (Wall 0.000419542s, CPU 0.0005s)
# Info    : Meshing 2D...
# Info    : [  0%] Meshing surface 1 (Plane, Frontal-Delaunay)
# Info    : [ 20%] Meshing surface 2 (Plane, Frontal-Delaunay)
# Info    : [ 40%] Meshing surface 3 (Plane, Frontal-Delaunay)
# Info    : [ 60%] Meshing surface 4 (Plane, Frontal-Delaunay)
# Info    : [ 70%] Meshing surface 5 (Plane, Frontal-Delaunay)
# Info    : [ 90%] Meshing surface 6 (Plane, Frontal-Delaunay)
# Info    : Done meshing 2D (Wall 0.00168187s, CPU 0.001725s)
# Info    : 100 nodes 260 elements
# Info    : Writing 'relaxed_state/simple_domain_ECV_0.25/cuboid_0.msh'...
# Info    : Done writing 'relaxed_state/simple_domain_ECV_0.25/cuboid_0.msh'
#
# Mesh successfully exported to simple_domain/cuboid_0.off
# Info    : Increasing process stack size (8176 kB < 16 MB)
# Info    : Meshing 1D...
# Info    : [  0%] Meshing curve 1 (Line)
# Info    : [ 10%] Meshing curve 2 (Line)
# Info    : [ 20%] Meshing curve 3 (Line)
# Info    : [ 30%] Meshing curve 4 (Line)
# Info    : [ 40%] Meshing curve 5 (Line)
# Info    : [ 50%] Meshing curve 6 (Line)
# Info    : [ 60%] Meshing curve 7 (Line)
# Info    : [ 60%] Meshing curve 8 (Line)
# Info    : [ 70%] Meshing curve 9 (Line)
# Info    : [ 80%] Meshing curve 10 (Line)
# Info    : [ 90%] Meshing curve 11 (Line)
# Info    : [100%] Meshing curve 12 (Line)
# Info    : Done meshing 1D (Wall 0.000412833s, CPU 0.000461s)
# Info    : Meshing 2D...
# Info    : [  0%] Meshing surface 1 (Plane, Frontal-Delaunay)
# Info    : [ 20%] Meshing surface 2 (Plane, Frontal-Delaunay)
# Info    : [ 40%] Meshing surface 3 (Plane, Frontal-Delaunay)
# Info    : [ 60%] Meshing surface 4 (Plane, Frontal-Delaunay)
# Info    : [ 70%] Meshing surface 5 (Plane, Frontal-Delaunay)
# Info    : [ 90%] Meshing surface 6 (Plane, Frontal-Delaunay)
# Info    : Done meshing 2D (Wall 0.00179004s, CPU 0.00181s)
# Info    : 100 nodes 260 elements
# Info    : Writing 'relaxed_state/simple_domain_ECV_0.25/cuboid_1.msh'...
# Info    : Done writing 'relaxed_state/simple_domain_ECV_0.25/cuboid_1.msh'
#
# Mesh successfully exported to simple_domain/cuboid_0.off
# Info    : Increasing process stack size (8176 kB < 16 MB)
# Info    : Meshing 1D...
# Info    : [  0%] Meshing curve 1 (Line)
# Info    : [ 10%] Meshing curve 2 (Line)
# Info    : [ 20%] Meshing curve 3 (Line)
# Info    : [ 30%] Meshing curve 4 (Line)
# Info    : [ 40%] Meshing curve 5 (Line)
# Info    : [ 50%] Meshing curve 6 (Line)
# Info    : [ 60%] Meshing curve 7 (Line)
# Info    : [ 60%] Meshing curve 8 (Line)
# Info    : [ 70%] Meshing curve 9 (Line)
# Info    : [ 80%] Meshing curve 10 (Line)
# Info    : [ 90%] Meshing curve 11 (Line)
# Info    : [100%] Meshing curve 12 (Line)
# Info    : Done meshing 1D (Wall 0.000420208s, CPU 0.000497s)
# Info    : Meshing 2D...
# Info    : [  0%] Meshing surface 1 (Plane, Frontal-Delaunay)
# Info    : [ 20%] Meshing surface 2 (Plane, Frontal-Delaunay)
# Info    : [ 40%] Meshing surface 3 (Plane, Frontal-Delaunay)
# Info    : [ 60%] Meshing surface 4 (Plane, Frontal-Delaunay)
# Info    : [ 70%] Meshing surface 5 (Plane, Frontal-Delaunay)
# Info    : [ 90%] Meshing surface 6 (Plane, Frontal-Delaunay)
# Info    : Done meshing 2D (Wall 0.00180263s, CPU 0.001824s)
# Info    : 100 nodes 260 elements
# Info    : Writing 'relaxed_state/simple_domain_ECV_0.25/cuboid_2.msh'...
# Info    : Done writing 'relaxed_state/simple_domain_ECV_0.25/cuboid_2.msh'
#
# Mesh successfully exported to simple_domain/cuboid_0.off
# Info    : Increasing process stack size (8176 kB < 16 MB)
# Info    : Meshing 1D...
# Info    : [  0%] Meshing curve 1 (Line)
# Info    : [ 10%] Meshing curve 2 (Line)
# Info    : [ 20%] Meshing curve 3 (Line)
# Info    : [ 30%] Meshing curve 4 (Line)
# Info    : [ 40%] Meshing curve 5 (Line)
# Info    : [ 50%] Meshing curve 6 (Line)
# Info    : [ 60%] Meshing curve 7 (Line)
# Info    : [ 60%] Meshing curve 8 (Line)
# Info    : [ 70%] Meshing curve 9 (Line)
# Info    : [ 80%] Meshing curve 10 (Line)
# Info    : [ 90%] Meshing curve 11 (Line)
# Info    : [100%] Meshing curve 12 (Line)
# Info    : Done meshing 1D (Wall 0.000403625s, CPU 0.000444s)
# Info    : Meshing 2D...
# Info    : [  0%] Meshing surface 1 (Plane, Frontal-Delaunay)
# Info    : [ 20%] Meshing surface 2 (Plane, Frontal-Delaunay)
# Info    : [ 40%] Meshing surface 3 (Plane, Frontal-Delaunay)
# Info    : [ 60%] Meshing surface 4 (Plane, Frontal-Delaunay)
# Info    : [ 70%] Meshing surface 5 (Plane, Frontal-Delaunay)
# Info    : [ 90%] Meshing surface 6 (Plane, Frontal-Delaunay)
# Info    : Done meshing 2D (Wall 0.00168554s, CPU 0.001694s)
# Info    : 100 nodes 260 elements
# Info    : Writing 'relaxed_state/simple_domain_ECV_0.25/cuboid_3.msh'...
# Info    : Done writing 'relaxed_state/simple_domain_ECV_0.25/cuboid_3.msh'
#
# Mesh successfully exported to simple_domain/cuboid_0.off
# Info    : Increasing process stack size (8176 kB < 16 MB)
# Info    : Meshing 1D...
# Info    : [  0%] Meshing curve 1 (Line)
# Info    : [ 10%] Meshing curve 2 (Line)
# Info    : [ 20%] Meshing curve 3 (Line)
# Info    : [ 30%] Meshing curve 4 (Line)
# Info    : [ 40%] Meshing curve 5 (Line)
# Info    : [ 50%] Meshing curve 6 (Line)
# Info    : [ 60%] Meshing curve 7 (Line)
# Info    : [ 60%] Meshing curve 8 (Line)
# Info    : [ 70%] Meshing curve 9 (Line)
# Info    : [ 80%] Meshing curve 10 (Line)
# Info    : [ 90%] Meshing curve 11 (Line)
# Info    : [100%] Meshing curve 12 (Line)
# Info    : Done meshing 1D (Wall 0.000403416s, CPU 0.000451s)
# Info    : Meshing 2D...
# Info    : [  0%] Meshing surface 1 (Plane, Frontal-Delaunay)
# Info    : [ 20%] Meshing surface 2 (Plane, Frontal-Delaunay)
# Info    : [ 40%] Meshing surface 3 (Plane, Frontal-Delaunay)
# Info    : [ 60%] Meshing surface 4 (Plane, Frontal-Delaunay)
# Info    : [ 70%] Meshing surface 5 (Plane, Frontal-Delaunay)
# Info    : [ 90%] Meshing surface 6 (Plane, Frontal-Delaunay)
# Info    : Done meshing 2D (Wall 0.00167008s, CPU 0.001691s)
# Info    : 100 nodes 260 elements
# Info    : Writing 'relaxed_state/simple_domain_ECV_0.25/cuboid_4.msh'...
# Info    : Done writing 'relaxed_state/simple_domain_ECV_0.25/cuboid_4.msh'
#
# Mesh successfully exported to simple_domain/cuboid_0.off
# Info    : Increasing process stack size (8176 kB < 16 MB)
# Info    : Meshing 1D...
# Info    : [  0%] Meshing curve 1 (Line)
# Info    : [ 10%] Meshing curve 2 (Line)
# Info    : [ 20%] Meshing curve 3 (Line)
# Info    : [ 30%] Meshing curve 4 (Line)
# Info    : [ 40%] Meshing curve 5 (Line)
# Info    : [ 50%] Meshing curve 6 (Line)
# Info    : [ 60%] Meshing curve 7 (Line)
# Info    : [ 60%] Meshing curve 8 (Line)
# Info    : [ 70%] Meshing curve 9 (Line)
# Info    : [ 80%] Meshing curve 10 (Line)
# Info    : [ 90%] Meshing curve 11 (Line)
# Info    : [100%] Meshing curve 12 (Line)
# Info    : Done meshing 1D (Wall 0.000414s, CPU 0.000458s)
# Info    : Meshing 2D...
# Info    : [  0%] Meshing surface 1 (Plane, Frontal-Delaunay)
# Info    : [ 20%] Meshing surface 2 (Plane, Frontal-Delaunay)
# Info    : [ 40%] Meshing surface 3 (Plane, Frontal-Delaunay)
# Info    : [ 60%] Meshing surface 4 (Plane, Frontal-Delaunay)
# Info    : [ 70%] Meshing surface 5 (Plane, Frontal-Delaunay)
# Info    : [ 90%] Meshing surface 6 (Plane, Frontal-Delaunay)
# Info    : Done meshing 2D (Wall 0.0018685s, CPU 0.00186s)
# Info    : 100 nodes 260 elements
# Info    : Writing 'relaxed_state/simple_domain_ECV_0.25/cuboid_5.msh'...
# Info    : Done writing 'relaxed_state/simple_domain_ECV_0.25/cuboid_5.msh'
#
# Mesh successfully exported to simple_domain/cuboid_0.off
# Info    : Increasing process stack size (8176 kB < 16 MB)
# Info    : Meshing 1D...
# Info    : [  0%] Meshing curve 1 (Line)
# Info    : [ 10%] Meshing curve 2 (Line)
# Info    : [ 20%] Meshing curve 3 (Line)
# Info    : [ 30%] Meshing curve 4 (Line)
# Info    : [ 40%] Meshing curve 5 (Line)
# Info    : [ 50%] Meshing curve 6 (Line)
# Info    : [ 60%] Meshing curve 7 (Line)
# Info    : [ 60%] Meshing curve 8 (Line)
# Info    : [ 70%] Meshing curve 9 (Line)
# Info    : [ 80%] Meshing curve 10 (Line)
# Info    : [ 90%] Meshing curve 11 (Line)
# Info    : [100%] Meshing curve 12 (Line)
# Info    : Done meshing 1D (Wall 0.000485208s, CPU 0.000541s)
# Info    : Meshing 2D...
# Info    : [  0%] Meshing surface 1 (Plane, Frontal-Delaunay)
# Info    : [ 20%] Meshing surface 2 (Plane, Frontal-Delaunay)
# Info    : [ 40%] Meshing surface 3 (Plane, Frontal-Delaunay)
# Info    : [ 60%] Meshing surface 4 (Plane, Frontal-Delaunay)
# Info    : [ 70%] Meshing surface 5 (Plane, Frontal-Delaunay)
# Info    : [ 90%] Meshing surface 6 (Plane, Frontal-Delaunay)
# Info    : Done meshing 2D (Wall 0.00159917s, CPU 0.001627s)
# Info    : 100 nodes 260 elements
# Info    : Writing 'relaxed_state/simple_domain_ECV_0.25/cuboid_6.msh'...
# Info    : Done writing 'relaxed_state/simple_domain_ECV_0.25/cuboid_6.msh'
#
# Mesh successfully exported to simple_domain/cuboid_0.off
# Info    : Increasing process stack size (8176 kB < 16 MB)
# Info    : Meshing 1D...
# Info    : [  0%] Meshing curve 1 (Line)
# Info    : [ 10%] Meshing curve 2 (Line)
# Info    : [ 20%] Meshing curve 3 (Line)
# Info    : [ 30%] Meshing curve 4 (Line)
# Info    : [ 40%] Meshing curve 5 (Line)
# Info    : [ 50%] Meshing curve 6 (Line)
# Info    : [ 60%] Meshing curve 7 (Line)
# Info    : [ 60%] Meshing curve 8 (Line)
# Info    : [ 70%] Meshing curve 9 (Line)
# Info    : [ 80%] Meshing curve 10 (Line)
# Info    : [ 90%] Meshing curve 11 (Line)
# Info    : [100%] Meshing curve 12 (Line)
# Info    : Done meshing 1D (Wall 0.000438833s, CPU 0.000477s)
# Info    : Meshing 2D...
# Info    : [  0%] Meshing surface 1 (Plane, Frontal-Delaunay)
# Info    : [ 20%] Meshing surface 2 (Plane, Frontal-Delaunay)
# Info    : [ 40%] Meshing surface 3 (Plane, Frontal-Delaunay)
# Info    : [ 60%] Meshing surface 4 (Plane, Frontal-Delaunay)
# Info    : [ 70%] Meshing surface 5 (Plane, Frontal-Delaunay)
# Info    : [ 90%] Meshing surface 6 (Plane, Frontal-Delaunay)
# Info    : Done meshing 2D (Wall 0.00158158s, CPU 0.001599s)
# Info    : 100 nodes 260 elements
# Info    : Writing 'relaxed_state/simple_domain_ECV_0.25/cuboid_7.msh'...
# Info    : Done writing 'relaxed_state/simple_domain_ECV_0.25/cuboid_7.msh'
#
# Mesh successfully exported to simple_domain/cuboid_0.off
# Info    : Increasing process stack size (8176 kB < 16 MB)
# Info    : Meshing 1D...
# Info    : [  0%] Meshing curve 1 (Line)
# Info    : [ 10%] Meshing curve 2 (Line)
# Info    : [ 20%] Meshing curve 3 (Line)
# Info    : [ 30%] Meshing curve 4 (Line)
# Info    : [ 40%] Meshing curve 5 (Line)
# Info    : [ 50%] Meshing curve 6 (Line)
# Info    : [ 60%] Meshing curve 7 (Line)
# Info    : [ 60%] Meshing curve 8 (Line)
# Info    : [ 70%] Meshing curve 9 (Line)
# Info    : [ 80%] Meshing curve 10 (Line)
# Info    : [ 90%] Meshing curve 11 (Line)
# Info    : [100%] Meshing curve 12 (Line)
# Info    : Done meshing 1D (Wall 0.000434625s, CPU 0.00051s)
# Info    : Meshing 2D...
# Info    : [  0%] Meshing surface 1 (Plane, Frontal-Delaunay)
# Info    : [ 20%] Meshing surface 2 (Plane, Frontal-Delaunay)
# Info    : [ 40%] Meshing surface 3 (Plane, Frontal-Delaunay)
# Info    : [ 60%] Meshing surface 4 (Plane, Frontal-Delaunay)
# Info    : [ 70%] Meshing surface 5 (Plane, Frontal-Delaunay)
# Info    : [ 90%] Meshing surface 6 (Plane, Frontal-Delaunay)
# Info    : Done meshing 2D (Wall 0.00196904s, CPU 0.001973s)
# Info    : 100 nodes 260 elements
# Info    : Writing 'relaxed_state/simple_domain_ECV_0.25/cuboid_8.msh'...
# Info    : Done writing 'relaxed_state/simple_domain_ECV_0.25/cuboid_8.msh'
#
# Mesh successfully exported to simple_domain/cuboid_0.off
# ECV = 18.13%
# Info    : Increasing process stack size (8176 kB < 16 MB)
# Info    : Meshing 1D...
# Info    : [  0%] Meshing curve 1 (Line)
# Info    : [ 10%] Meshing curve 2 (Line)
# Info    : [ 20%] Meshing curve 3 (Line)
# Info    : [ 30%] Meshing curve 4 (Line)
# Info    : [ 40%] Meshing curve 5 (Line)
# Info    : [ 50%] Meshing curve 6 (Line)
# Info    : [ 60%] Meshing curve 7 (Line)
# Info    : [ 60%] Meshing curve 8 (Line)
# Info    : [ 70%] Meshing curve 9 (Line)
# Info    : [ 80%] Meshing curve 10 (Line)
# Info    : [ 90%] Meshing curve 11 (Line)
# Info    : [100%] Meshing curve 12 (Line)
# Info    : Done meshing 1D (Wall 0.000442625s, CPU 0.000547s)
# Info    : Meshing 2D...
# Info    : [  0%] Meshing surface 1 (Plane, Frontal-Delaunay)
# Info    : [ 20%] Meshing surface 2 (Plane, Frontal-Delaunay)
# Info    : [ 40%] Meshing surface 3 (Plane, Frontal-Delaunay)
# Info    : [ 60%] Meshing surface 4 (Plane, Frontal-Delaunay)
# Info    : [ 70%] Meshing surface 5 (Plane, Frontal-Delaunay)
# Info    : [ 90%] Meshing surface 6 (Plane, Frontal-Delaunay)
# Info    : Done meshing 2D (Wall 0.001805s, CPU 0.001816s)
# Info    : 100 nodes 260 elements
# Info    : Writing 'relaxed_state/simple_domain_ECV_0.18/cuboid_0.msh'...
# Info    : Done writing 'relaxed_state/simple_domain_ECV_0.18/cuboid_0.msh'
#
# Mesh successfully exported to simple_domain/cuboid_0.off
# Info    : Increasing process stack size (8176 kB < 16 MB)
# Info    : Meshing 1D...
# Info    : [  0%] Meshing curve 1 (Line)
# Info    : [ 10%] Meshing curve 2 (Line)
# Info    : [ 20%] Meshing curve 3 (Line)
# Info    : [ 30%] Meshing curve 4 (Line)
# Info    : [ 40%] Meshing curve 5 (Line)
# Info    : [ 50%] Meshing curve 6 (Line)
# Info    : [ 60%] Meshing curve 7 (Line)
# Info    : [ 60%] Meshing curve 8 (Line)
# Info    : [ 70%] Meshing curve 9 (Line)
# Info    : [ 80%] Meshing curve 10 (Line)
# Info    : [ 90%] Meshing curve 11 (Line)
# Info    : [100%] Meshing curve 12 (Line)
# Info    : Done meshing 1D (Wall 0.000460917s, CPU 0.000513s)
# Info    : Meshing 2D...
# Info    : [  0%] Meshing surface 1 (Plane, Frontal-Delaunay)
# Info    : [ 20%] Meshing surface 2 (Plane, Frontal-Delaunay)
# Info    : [ 40%] Meshing surface 3 (Plane, Frontal-Delaunay)
# Info    : [ 60%] Meshing surface 4 (Plane, Frontal-Delaunay)
# Info    : [ 70%] Meshing surface 5 (Plane, Frontal-Delaunay)
# Info    : [ 90%] Meshing surface 6 (Plane, Frontal-Delaunay)
# Info    : Done meshing 2D (Wall 0.00204792s, CPU 0.002533s)
# Info    : 100 nodes 260 elements
# Info    : Writing 'relaxed_state/simple_domain_ECV_0.18/cuboid_1.msh'...
# Info    : Done writing 'relaxed_state/simple_domain_ECV_0.18/cuboid_1.msh'
#
# Mesh successfully exported to simple_domain/cuboid_0.off
# Info    : Increasing process stack size (8176 kB < 16 MB)
# Info    : Meshing 1D...
# Info    : [  0%] Meshing curve 1 (Line)
# Info    : [ 10%] Meshing curve 2 (Line)
# Info    : [ 20%] Meshing curve 3 (Line)
# Info    : [ 30%] Meshing curve 4 (Line)
# Info    : [ 40%] Meshing curve 5 (Line)
# Info    : [ 50%] Meshing curve 6 (Line)
# Info    : [ 60%] Meshing curve 7 (Line)
# Info    : [ 60%] Meshing curve 8 (Line)
# Info    : [ 70%] Meshing curve 9 (Line)
# Info    : [ 80%] Meshing curve 10 (Line)
# Info    : [ 90%] Meshing curve 11 (Line)
# Info    : [100%] Meshing curve 12 (Line)
# Info    : Done meshing 1D (Wall 0.000623667s, CPU 0.000698s)
# Info    : Meshing 2D...
# Info    : [  0%] Meshing surface 1 (Plane, Frontal-Delaunay)
# Info    : [ 20%] Meshing surface 2 (Plane, Frontal-Delaunay)
# Info    : [ 40%] Meshing surface 3 (Plane, Frontal-Delaunay)
# Info    : [ 60%] Meshing surface 4 (Plane, Frontal-Delaunay)
# Info    : [ 70%] Meshing surface 5 (Plane, Frontal-Delaunay)
# Info    : [ 90%] Meshing surface 6 (Plane, Frontal-Delaunay)
# Info    : Done meshing 2D (Wall 0.00209367s, CPU 0.002129s)
# Info    : 100 nodes 260 elements
# Info    : Writing 'relaxed_state/simple_domain_ECV_0.18/cuboid_2.msh'...
# Info    : Done writing 'relaxed_state/simple_domain_ECV_0.18/cuboid_2.msh'
#
# Mesh successfully exported to simple_domain/cuboid_0.off
# Info    : Increasing process stack size (8176 kB < 16 MB)
# Info    : Meshing 1D...
# Info    : [  0%] Meshing curve 1 (Line)
# Info    : [ 10%] Meshing curve 2 (Line)
# Info    : [ 20%] Meshing curve 3 (Line)
# Info    : [ 30%] Meshing curve 4 (Line)
# Info    : [ 40%] Meshing curve 5 (Line)
# Info    : [ 50%] Meshing curve 6 (Line)
# Info    : [ 60%] Meshing curve 7 (Line)
# Info    : [ 60%] Meshing curve 8 (Line)
# Info    : [ 70%] Meshing curve 9 (Line)
# Info    : [ 80%] Meshing curve 10 (Line)
# Info    : [ 90%] Meshing curve 11 (Line)
# Info    : [100%] Meshing curve 12 (Line)
# Info    : Done meshing 1D (Wall 0.000506042s, CPU 0.000588s)
# Info    : Meshing 2D...
# Info    : [  0%] Meshing surface 1 (Plane, Frontal-Delaunay)
# Info    : [ 20%] Meshing surface 2 (Plane, Frontal-Delaunay)
# Info    : [ 40%] Meshing surface 3 (Plane, Frontal-Delaunay)
# Info    : [ 60%] Meshing surface 4 (Plane, Frontal-Delaunay)
# Info    : [ 70%] Meshing surface 5 (Plane, Frontal-Delaunay)
# Info    : [ 90%] Meshing surface 6 (Plane, Frontal-Delaunay)
# Info    : Done meshing 2D (Wall 0.00213071s, CPU 0.002161s)
# Info    : 100 nodes 260 elements
# Info    : Writing 'relaxed_state/simple_domain_ECV_0.18/cuboid_3.msh'...
# Info    : Done writing 'relaxed_state/simple_domain_ECV_0.18/cuboid_3.msh'
#
# Mesh successfully exported to simple_domain/cuboid_0.off
# Info    : Increasing process stack size (8176 kB < 16 MB)
# Info    : Meshing 1D...
# Info    : [  0%] Meshing curve 1 (Line)
# Info    : [ 10%] Meshing curve 2 (Line)
# Info    : [ 20%] Meshing curve 3 (Line)
# Info    : [ 30%] Meshing curve 4 (Line)
# Info    : [ 40%] Meshing curve 5 (Line)
# Info    : [ 50%] Meshing curve 6 (Line)
# Info    : [ 60%] Meshing curve 7 (Line)
# Info    : [ 60%] Meshing curve 8 (Line)
# Info    : [ 70%] Meshing curve 9 (Line)
# Info    : [ 80%] Meshing curve 10 (Line)
# Info    : [ 90%] Meshing curve 11 (Line)
# Info    : [100%] Meshing curve 12 (Line)
# Info    : Done meshing 1D (Wall 0.000473458s, CPU 0.00052s)
# Info    : Meshing 2D...
# Info    : [  0%] Meshing surface 1 (Plane, Frontal-Delaunay)
# Info    : [ 20%] Meshing surface 2 (Plane, Frontal-Delaunay)
# Info    : [ 40%] Meshing surface 3 (Plane, Frontal-Delaunay)
# Info    : [ 60%] Meshing surface 4 (Plane, Frontal-Delaunay)
# Info    : [ 70%] Meshing surface 5 (Plane, Frontal-Delaunay)
# Info    : [ 90%] Meshing surface 6 (Plane, Frontal-Delaunay)
# Info    : Done meshing 2D (Wall 0.00188687s, CPU 0.001909s)
# Info    : 100 nodes 260 elements
# Info    : Writing 'relaxed_state/simple_domain_ECV_0.18/cuboid_4.msh'...
# Info    : Done writing 'relaxed_state/simple_domain_ECV_0.18/cuboid_4.msh'
#
# Mesh successfully exported to simple_domain/cuboid_0.off
# Info    : Increasing process stack size (8176 kB < 16 MB)
# Info    : Meshing 1D...
# Info    : [  0%] Meshing curve 1 (Line)
# Info    : [ 10%] Meshing curve 2 (Line)
# Info    : [ 20%] Meshing curve 3 (Line)
# Info    : [ 30%] Meshing curve 4 (Line)
# Info    : [ 40%] Meshing curve 5 (Line)
# Info    : [ 50%] Meshing curve 6 (Line)
# Info    : [ 60%] Meshing curve 7 (Line)
# Info    : [ 60%] Meshing curve 8 (Line)
# Info    : [ 70%] Meshing curve 9 (Line)
# Info    : [ 80%] Meshing curve 10 (Line)
# Info    : [ 90%] Meshing curve 11 (Line)
# Info    : [100%] Meshing curve 12 (Line)
# Info    : Done meshing 1D (Wall 0.000524458s, CPU 0.000627s)
# Info    : Meshing 2D...
# Info    : [  0%] Meshing surface 1 (Plane, Frontal-Delaunay)
# Info    : [ 20%] Meshing surface 2 (Plane, Frontal-Delaunay)
# Info    : [ 40%] Meshing surface 3 (Plane, Frontal-Delaunay)
# Info    : [ 60%] Meshing surface 4 (Plane, Frontal-Delaunay)
# Info    : [ 70%] Meshing surface 5 (Plane, Frontal-Delaunay)
# Info    : [ 90%] Meshing surface 6 (Plane, Frontal-Delaunay)
# Info    : Done meshing 2D (Wall 0.00222737s, CPU 0.002261s)
# Info    : 100 nodes 260 elements
# Info    : Writing 'relaxed_state/simple_domain_ECV_0.18/cuboid_5.msh'...
# Info    : Done writing 'relaxed_state/simple_domain_ECV_0.18/cuboid_5.msh'
#
# Mesh successfully exported to simple_domain/cuboid_0.off
# Info    : Increasing process stack size (8176 kB < 16 MB)
# Info    : Meshing 1D...
# Info    : [  0%] Meshing curve 1 (Line)
# Info    : [ 10%] Meshing curve 2 (Line)
# Info    : [ 20%] Meshing curve 3 (Line)
# Info    : [ 30%] Meshing curve 4 (Line)
# Info    : [ 40%] Meshing curve 5 (Line)
# Info    : [ 50%] Meshing curve 6 (Line)
# Info    : [ 60%] Meshing curve 7 (Line)
# Info    : [ 60%] Meshing curve 8 (Line)
# Info    : [ 70%] Meshing curve 9 (Line)
# Info    : [ 80%] Meshing curve 10 (Line)
# Info    : [ 90%] Meshing curve 11 (Line)
# Info    : [100%] Meshing curve 12 (Line)
# Info    : Done meshing 1D (Wall 0.000496584s, CPU 0.000556s)
# Info    : Meshing 2D...
# Info    : [  0%] Meshing surface 1 (Plane, Frontal-Delaunay)
# Info    : [ 20%] Meshing surface 2 (Plane, Frontal-Delaunay)
# Info    : [ 40%] Meshing surface 3 (Plane, Frontal-Delaunay)
# Info    : [ 60%] Meshing surface 4 (Plane, Frontal-Delaunay)
# Info    : [ 70%] Meshing surface 5 (Plane, Frontal-Delaunay)
# Info    : [ 90%] Meshing surface 6 (Plane, Frontal-Delaunay)
# Info    : Done meshing 2D (Wall 0.00208783s, CPU 0.002113s)
# Info    : 100 nodes 260 elements
# Info    : Writing 'relaxed_state/simple_domain_ECV_0.18/cuboid_6.msh'...
# Info    : Done writing 'relaxed_state/simple_domain_ECV_0.18/cuboid_6.msh'
#
# Mesh successfully exported to simple_domain/cuboid_0.off
# Info    : Increasing process stack size (8176 kB < 16 MB)
# Info    : Meshing 1D...
# Info    : [  0%] Meshing curve 1 (Line)
# Info    : [ 10%] Meshing curve 2 (Line)
# Info    : [ 20%] Meshing curve 3 (Line)
# Info    : [ 30%] Meshing curve 4 (Line)
# Info    : [ 40%] Meshing curve 5 (Line)
# Info    : [ 50%] Meshing curve 6 (Line)
# Info    : [ 60%] Meshing curve 7 (Line)
# Info    : [ 60%] Meshing curve 8 (Line)
# Info    : [ 70%] Meshing curve 9 (Line)
# Info    : [ 80%] Meshing curve 10 (Line)
# Info    : [ 90%] Meshing curve 11 (Line)
# Info    : [100%] Meshing curve 12 (Line)
# Info    : Done meshing 1D (Wall 0.000666917s, CPU 0.000837s)
# Info    : Meshing 2D...
# Info    : [  0%] Meshing surface 1 (Plane, Frontal-Delaunay)
# Info    : [ 20%] Meshing surface 2 (Plane, Frontal-Delaunay)
# Info    : [ 40%] Meshing surface 3 (Plane, Frontal-Delaunay)
# Info    : [ 60%] Meshing surface 4 (Plane, Frontal-Delaunay)
# Info    : [ 70%] Meshing surface 5 (Plane, Frontal-Delaunay)
# Info    : [ 90%] Meshing surface 6 (Plane, Frontal-Delaunay)
# Info    : Done meshing 2D (Wall 0.00225567s, CPU 0.002294s)
# Info    : 100 nodes 260 elements
# Info    : Writing 'relaxed_state/simple_domain_ECV_0.18/cuboid_7.msh'...
# Info    : Done writing 'relaxed_state/simple_domain_ECV_0.18/cuboid_7.msh'
#
# Mesh successfully exported to simple_domain/cuboid_0.off
# Info    : Increasing process stack size (8176 kB < 16 MB)
# Info    : Meshing 1D...
# Info    : [  0%] Meshing curve 1 (Line)
# Info    : [ 10%] Meshing curve 2 (Line)
# Info    : [ 20%] Meshing curve 3 (Line)
# Info    : [ 30%] Meshing curve 4 (Line)
# Info    : [ 40%] Meshing curve 5 (Line)
# Info    : [ 50%] Meshing curve 6 (Line)
# Info    : [ 60%] Meshing curve 7 (Line)
# Info    : [ 60%] Meshing curve 8 (Line)
# Info    : [ 70%] Meshing curve 9 (Line)
# Info    : [ 80%] Meshing curve 10 (Line)
# Info    : [ 90%] Meshing curve 11 (Line)
# Info    : [100%] Meshing curve 12 (Line)
# Info    : Done meshing 1D (Wall 0.000469583s, CPU 0.000561s)
# Info    : Meshing 2D...
# Info    : [  0%] Meshing surface 1 (Plane, Frontal-Delaunay)
# Info    : [ 20%] Meshing surface 2 (Plane, Frontal-Delaunay)
# Info    : [ 40%] Meshing surface 3 (Plane, Frontal-Delaunay)
# Info    : [ 60%] Meshing surface 4 (Plane, Frontal-Delaunay)
# Info    : [ 70%] Meshing surface 5 (Plane, Frontal-Delaunay)
# Info    : [ 90%] Meshing surface 6 (Plane, Frontal-Delaunay)
# Info    : Done meshing 2D (Wall 0.00192712s, CPU 0.001991s)
# Info    : 100 nodes 260 elements
# Info    : Writing 'relaxed_state/simple_domain_ECV_0.18/cuboid_8.msh'...
# Info    : Done writing 'relaxed_state/simple_domain_ECV_0.18/cuboid_8.msh'
#
# Mesh successfully exported to simple_domain/cuboid_0.off

# %%
#double checking ECV an watertight
def check_ECV_and_watertight(root_dir, block_x_original, block_y_original, block_z_original):
    dirs = os.listdir(root_dir)
    files = []
    ecvs = []
    for dir in dirs:
        files_in_dir = os.listdir(f"{root_dir}/{dir}/")
        files_in_dir = [file for file in files_in_dir if file.endswith(".ply")]
        v_ics = 0
        for file in files_in_dir:
            #load in trimesh
            mesh_check = trimesh.load(f"{root_dir}/{dir}/{file}")
            #check if mesh is watertight
            if not mesh_check.is_watertight:
                print("Mesh is not watertight.")
                raise RuntimeError("Mesh is not watertight.")
            #compute volume
            volume = mesh_check.volume
            v_ics += volume
        ecv = 1 - v_ics/(block_x_original*block_y_original*block_z_original)
        ecvs.append(ecv)    
    return ecvs

ecvs_relaxed = check_ECV_and_watertight("relaxed_state", block_x_original, block_y_original, block_z_original)
print(ecvs_relaxed)
# Out:
# [0.25033005355255933, 0.4455441076074723, 0.18134167673073343]

# %%
def strain_geometry(block_x_original, block_y_original, block_z_original, strain_z, strain_x, strain_y, root_dir,final_dir):
    dirs = os.listdir(root_dir)
    files = []
    ecvs = []
    for dir in dirs:
        files_in_dir = os.listdir(f"{root_dir}/{dir}/")
        files_in_dir = [file for file in files_in_dir if file.endswith(".ply")]
        v_ics = 0
        for file in files_in_dir:
            #load in trimesh
            mesh_check = trimesh.load(f"{root_dir}/{dir}/{file}")
            #get vertices of the mesh
            vertices = mesh_check.vertices
            #apply strain
            vertices[:,2] = vertices[:,2]*(strain_z)
            vertices[:,0] = vertices[:,0]*(strain_x)
            vertices[:,1] = vertices[:,1]*(strain_y)
            
            #save mesh in final_dir
            file_name = file.split(".")[0]
            os.makedirs(f"{final_dir}/{dir}", exist_ok=True)
            mesh_check.export(f"{final_dir}/{dir}/{file_name}.ply", file_type="ply")
            mesh_check.export(f"{final_dir}/{dir}/{file_name}.off", file_type="off")
            #mesh_check.export(f"{final_dir}/{dir}/{file}", file_type="msh")
            
            #check if mesh is watertight
            if not mesh_check.is_watertight:
                print("Mesh is not watertight.")
                raise RuntimeError("Mesh is not watertight.")
            #compute volume
            volume = mesh_check.volume
            v_ics += volume
            
        block_x_original_strain = block_x_original*strain_x 
        block_y_original_strain = block_y_original*strain_y
        block_z_original_strain = block_z_original*strain_z
        ecv = 1 - v_ics/(block_x_original_strain*block_y_original_strain*block_z_original_strain)
        ecvs.append(ecv)    
    return ecvs

strain_z = 1-0.18
strain_x = np.sqrt(1/strain_z)
strain_y = np.sqrt(1/strain_z)
strain_geometry(block_x_original, block_y_original, block_z_original, strain_z, strain_x, strain_y, "relaxed_state", "compressed_state")
# Out:
# [0.250330053552559, 0.4455441076074722, 0.18134167673073298]
